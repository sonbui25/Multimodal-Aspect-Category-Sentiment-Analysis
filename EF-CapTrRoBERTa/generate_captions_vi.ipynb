# %%
# !rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
# !git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# Out:
# Cloning into 'Multimodal-Aspect-Category-Sentiment-Analysis'...
# remote: Enumerating objects: 1080, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 1080 (delta 321), reused 308 (delta 277), pack-reused 725 (from 2)
# Receiving objects: 100% (1080/1080), 3.00 MiB | 24.57 MiB/s, done.
# Resolving deltas: 100% (694/694), done.

# %%
#!pip install -r '/kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/requirements.txt'
# !pip install underthesea
# !pip install underthesea_core
# !pip install huggingface-hub==0.17.3
# !pip install transformers==4.35.0
# !pip install bert-score
# !pip install rouge-score
# !pip install protobuf==3.20.3
# Out:
# Collecting underthesea
#   Downloading underthesea-8.3.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.12/dist-packages (from underthesea) (8.3.1)
# Collecting python-crfsuite>=0.9.6 (from underthesea)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: nltk>=3.8 in /usr/local/lib/python3.12/dist-packages (from underthesea) (3.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from underthesea) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from underthesea) (2.32.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from underthesea) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from underthesea) (1.6.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from underthesea) (6.0.3)
# Collecting underthesea_core==1.0.5 (from underthesea)
#   Downloading underthesea_core-1.0.5-cp312-cp312-manylinux2010_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from underthesea) (0.36.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.8->underthesea) (2025.11.3)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (1.2.1rc0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (2025.11.12)
# Downloading underthesea-8.3.0-py3-none-any.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 65.0 MB/s eta 0:00:00
# Downloading underthesea_core-1.0.5-cp312-cp312-manylinux2010_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.4/978.4 kB 48.5 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.7 MB/s eta 0:00:00
# Installing collected packages: underthesea_core, python-crfsuite, underthesea
# Successfully installed python-crfsuite-0.9.12 underthesea-8.3.0 underthesea_core-1.0.5
# Requirement already satisfied: underthesea_core in /usr/local/lib/python3.12/dist-packages (1.0.5)
# Collecting huggingface-hub==0.17.3
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (3.20.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (2025.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (4.15.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.17.3) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.17.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.17.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.17.3) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.17.3) (2025.11.12)
# Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.4.1 requires huggingface-hub<2.0,>=0.25.0, but you have huggingface-hub 0.17.3 which is incompatible.
# accelerate 1.11.0 requires huggingface_hub>=0.21.0, but you have huggingface-hub 0.17.3 which is incompatible.
# sentence-transformers 5.1.1 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.17.3 which is incompatible.
# gradio-client 1.13.3 requires huggingface-hub<2.0,>=0.19.3, but you have huggingface-hub 0.17.3 which is incompatible.
# gradio 5.49.1 requires huggingface-hub<2.0,>=0.33.5, but you have huggingface-hub 0.17.3 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# peft 0.17.1 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.17.3 which is incompatible.
# diffusers 0.35.2 requires huggingface-hub>=0.34.0, but you have huggingface-hub 0.17.3 which is incompatible.
# transformers 4.57.1 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 0.17.3 which is incompatible.
# Successfully installed huggingface-hub-0.17.3
# Collecting transformers==4.35.0
#   Downloading transformers-4.35.0-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (3.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (2.32.5)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.35.0)
#   Downloading tokenizers-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.0) (4.67.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.0) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.0) (2025.11.12)
# Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 77.2 MB/s eta 0:00:00
# Downloading tokenizers-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 99.8 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.1 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.17.3 which is incompatible.
# sentence-transformers 5.1.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.35.0 which is incompatible.
# peft 0.17.1 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.17.3 which is incompatible.
# Successfully installed tokenizers-0.14.1 transformers-4.35.0
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.35.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.5)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (2025.11.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge-score) (3.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=fb291737a79b1997a3bad008ef0f106e17337efd188b990a7a797b9a4f386624
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.20.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ray 2.52.1 requires click!=8.3.*,>=7.0, but you have click 8.3.1 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
# !pip install --upgrade transformers huggingface-hub accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.35.0)
# Collecting transformers
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (0.17.3)
# Collecting huggingface-hub
#   Downloading huggingface_hub-1.3.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Collecting accelerate
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.1)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (1.2.1rc0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 116.9 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 34.8 MB/s eta 0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 28.3 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 103.2 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, tokenizers, transformers, accelerate
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.0
#     Uninstalling transformers-4.35.0:
#       Successfully uninstalled transformers-4.35.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.11.0
#     Uninstalling accelerate-1.11.0:
#       Successfully uninstalled accelerate-1.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# Successfully installed accelerate-1.12.0 huggingface-hub-0.36.0 tokenizers-0.22.2 transformers-4.57.6

# %%
# !mkdir -p /kaggle/working/ViMACSA/output/pretraining

# %%
# # Bước 1: Image categories
'''
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/image_processing/run_image_categories.py \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
   --image_label_path "/kaggle/input/all-image-label/all_image_label.xlsx" \
   --output_dir "/kaggle/working/ViMACSA/image_categories" \
   --do_train \
   --get_cate \
   --train_batch_size 64 \
   --eval_batch_size 64 \
   --num_train_epochs 30 \
   --learning_rate 2e-5 \
   --seed 42
'''
# Out:
# '\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/image_processing/run_image_categories.py   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"    --image_label_path "/kaggle/input/all-image-label/all_image_label.xlsx"    --output_dir "/kaggle/working/ViMACSA/image_categories"    --do_train    --get_cate    --train_batch_size 64    --eval_batch_size 64    --num_train_epochs 30    --learning_rate 2e-5    --seed 42\n'

# %%
'''
#Bước 2: ROI categories
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/image_processing/run_roi_categories.py \
    --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
    --roi_label_path "/kaggle/input/vimacsa/ViMACSA/roi_data.csv" \
    --output_dir "/kaggle/working/ViMACSA/roi_categories" \
    --do_train \
    --get_cate \
    --train_batch_size 64 \
    --eval_batch_size 64 \
    --num_train_epochs 30 \
    --learning_rate 2e-5 \
    --seed 42
'''
# Out:
# '\n#Bước 2: ROI categories\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/image_processing/run_roi_categories.py     --image_dir "/kaggle/input/vimacsa/ViMACSA/image"     --roi_label_path "/kaggle/input/vimacsa/ViMACSA/roi_data.csv"     --output_dir "/kaggle/working/ViMACSA/roi_categories"     --do_train     --get_cate     --train_batch_size 64     --eval_batch_size 64     --num_train_epochs 30     --learning_rate 2e-5     --seed 42\n'

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
'''
# !python -u /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_pretraining_fcmf.py \
  --data_dir "/kaggle/input/vimacsa/ViMACSA" \
  --pretrained_data_dir "/kaggle/input/iaog-filter-balanced" \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_imgs 7 \
  --num_rois 4 \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1 \
  --bert_score_model vinai/phobert-large \
  --output_dir "/kaggle/working/ViMACSA/output/pretraining" \
  --train_batch_size 4 \
  --eval_batch_size 128 \
  --num_train_epochs 15 \
  --learning_rate 3e-5 \
  --warmup_proportion 0.1 \
  --alpha 1.0 \
  --do_train \
  --beam_size 2 \
  --gradient_accumulation_steps 1 \
  --max_len_decoder 8 \
  --do_eval \
  --fp16
'''
# Out:
# '\n!python -u /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_pretraining_fcmf.py   --data_dir "/kaggle/input/vimacsa/ViMACSA"   --pretrained_data_dir "/kaggle/input/iaog-filter-balanced"   --list_aspect Location Food Room Facilities Service Public_area   --num_imgs 7   --num_rois 4   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1   --bert_score_model vinai/phobert-large   --output_dir "/kaggle/working/ViMACSA/output/pretraining"   --train_batch_size 4   --eval_batch_size 128   --num_train_epochs 15   --learning_rate 3e-5   --warmup_proportion 0.1   --alpha 1.0   --do_train   --beam_size 2   --gradient_accumulation_steps 1   --max_len_decoder 8   --do_eval   --fp16\n'

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# 0.68 iaog
#--pretrained_iaog_path /kaggle/input/iaog/pytorch/epoch_0/9/seed_42_iaog_model_best.pth \
'''
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1 \
  --pretrained_iaog_path /kaggle/input/iaog/pytorch/epoch_0/9/seed_42_iaog_model_best.pth \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 64 \
  --num_train_epochs 13 \
  --encoder_learning_rate 3e-5 \
  --classifier_head_learning_rate 2e-4 \
  --warmup_proportion 0 \
  --gradient_accumulation_steps 2 \
  --do_train \
  --do_eval \
  --fp16 \
  --alpha 1
'''
# Out:
# '\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py   --data_dir "/kaggle/input/implicit-vimacsa"   --output_dir "/kaggle/working/ViMACSA/output"   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1   --pretrained_iaog_path /kaggle/input/iaog/pytorch/epoch_0/9/seed_42_iaog_model_best.pth   --list_aspect Location Food Room Facilities Service Public_area   --num_polarity 4   --num_imgs 7   --num_rois 4   --train_batch_size 4   --eval_batch_size 64   --num_train_epochs 13   --encoder_learning_rate 3e-5   --classifier_head_learning_rate 2e-4   --warmup_proportion 0   --gradient_accumulation_steps 2   --do_train   --do_eval   --fp16   --alpha 1\n'

# %%
'''
# !rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
# !git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# !torchrun --nproc_per_node=2 /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1 \
  --pretrained_iaog_path /kaggle/input/iaog-bert-score/pytorch/30_epoch/7/seed_42_iaog_model_best.pth \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 8 \
  --num_train_epochs 13 \
  --encoder_learning_rate 3e-5 \
  --classifier_head_learning_rate 5e-4 \
  --warmup_proportion 0 \
  --gradient_accumulation_steps 2 \
  --do_train \
  --do_eval \
  --fp16 \
  --alpha 1 \
  --ddp
'''
# Out:
# '\n!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis\n!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git\n!torchrun --nproc_per_node=2 /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py   --data_dir "/kaggle/input/implicit-vimacsa"   --output_dir "/kaggle/working/ViMACSA/output"   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1   --pretrained_iaog_path /kaggle/input/iaog-bert-score/pytorch/30_epoch/7/seed_42_iaog_model_best.pth   --list_aspect Location Food Room Facilities Service Public_area   --num_polarity 4   --num_imgs 7   --num_rois 4   --train_batch_size 4   --eval_batch_size 8   --num_train_epochs 13   --encoder_learning_rate 3e-5   --classifier_head_learning_rate 5e-4   --warmup_proportion 0   --gradient_accumulation_steps 2   --do_train   --do_eval   --fp16   --alpha 1   --ddp\n'

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# 0.71 baseline
'''
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output_iaog_fcmf" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1 \
  --pretrained_iaog_path /kaggle/input/iaog/pytorch/epoch_0/9/seed_42_iaog_model_best.pth \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 32 \
  --num_train_epochs 13 \
  --encoder_learning_rate 5e-5 \
  --classifier_head_learning_rate 5e-5 \
  --warmup_proportion 0 \
  --gradient_accumulation_steps 1 \
  --do_train \
  --do_eval \
  --fp16 \
  --alpha 1
'''
# Out:
# '\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py   --data_dir "/kaggle/input/implicit-vimacsa"   --output_dir "/kaggle/working/ViMACSA/output_iaog_fcmf"   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1   --pretrained_iaog_path /kaggle/input/iaog/pytorch/epoch_0/9/seed_42_iaog_model_best.pth   --list_aspect Location Food Room Facilities Service Public_area   --num_polarity 4   --num_imgs 7   --num_rois 4   --train_batch_size 4   --eval_batch_size 32   --num_train_epochs 13   --encoder_learning_rate 5e-5   --classifier_head_learning_rate 5e-5   --warmup_proportion 0   --gradient_accumulation_steps 1   --do_train   --do_eval   --fp16   --alpha 1\n'

# %% [markdown]
# # TomROBERTa

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
'''
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/tomROBERTa/train_tomroberta_vimacsa_full.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output_tomROBERTa" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model "/kaggle/input/uitnlpvisobert/pytorch/default/1" \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 64 \
  --num_train_epochs 13 \
  --learning_rate 3e-5 \
  --warmup_proportion 0.1 \
  --gradient_accumulation_steps 2 \
  --do_train \
  --do_eval \
  --fp16 \
  --seed 42
'''
# Out:
# '\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/tomROBERTa/train_tomroberta_vimacsa_full.py   --data_dir "/kaggle/input/implicit-vimacsa"   --output_dir "/kaggle/working/ViMACSA/output_tomROBERTa"   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model "/kaggle/input/uitnlpvisobert/pytorch/default/1"   --list_aspect Location Food Room Facilities Service Public_area   --num_polarity 4   --num_imgs 7   --num_rois 4   --train_batch_size 4   --eval_batch_size 64   --num_train_epochs 13   --learning_rate 3e-5   --warmup_proportion 0.1   --gradient_accumulation_steps 2   --do_train   --do_eval   --fp16   --seed 42\n'

# %% [markdown]
# # mROBERTa

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
'''
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/mROBERTa/train_mroberta_vimacsa_full.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output_mROBERTa" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model "/kaggle/input/uitnlpvisobert/pytorch/default/1" \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 64 \
  --num_train_epochs 13 \
  --learning_rate 3e-5 \
  --warmup_proportion 0.1 \
  --gradient_accumulation_steps 2 \
  --do_train \
  --do_eval \
  --fp16 \
  --seed 42
'''
# Out:
# '\n!python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/mROBERTa/train_mroberta_vimacsa_full.py   --data_dir "/kaggle/input/implicit-vimacsa"   --output_dir "/kaggle/working/ViMACSA/output_mROBERTa"   --image_dir "/kaggle/input/vimacsa/ViMACSA/image"   --pretrained_hf_model "/kaggle/input/uitnlpvisobert/pytorch/default/1"   --list_aspect Location Food Room Facilities Service Public_area   --num_polarity 4   --num_imgs 7   --num_rois 4   --train_batch_size 4   --eval_batch_size 64   --num_train_epochs 13   --learning_rate 3e-5   --warmup_proportion 0.1   --gradient_accumulation_steps 2   --do_train   --do_eval   --fp16   --seed 42\n'

# %% [markdown]
# # EF-CapTrRoBERTa

# %% [markdown]
# ## Generate caption

# %%
# !rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
# !git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/EF-CapTrRoBERTa/generate_captions_vi.py \
  --output_file "/kaggle/working/ViMACSA/output_EF-CapTrRoBERTa_visual_captions_vi" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --batch_size 32
# Out:
# Cloning into 'Multimodal-Aspect-Category-Sentiment-Analysis'...
# remote: Enumerating objects: 1080, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 1080 (delta 321), reused 308 (delta 277), pack-reused 725 (from 2)
# Receiving objects: 100% (1080/1080), 3.00 MiB | 25.38 MiB/s, done.
# Resolving deltas: 100% (694/694), done.
# 2026-01-17 07:56:33.164554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768636593.362797     128 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768636593.418165     128 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768636593.905809     128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768636593.905858     128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768636593.905866     128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768636593.905872     128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Running on cuda...
# Loading BLIP model...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json: 100%|████████████████| 287/287 [00:00<00:00, 1.38MB/s]
# tokenizer_config.json: 100%|███████████████████| 506/506 [00:00<00:00, 3.24MB/s]
# vocab.txt: 232kB [00:00, 13.1MB/s]
# tokenizer.json: 711kB [00:00, 44.6MB/s]
# special_tokens_map.json: 100%|██████████████████| 125/125 [00:00<00:00, 753kB/s]
# config.json: 4.56kB [00:00, 19.5MB/s]
# pytorch_model.bin: 100%|██████████████████████| 990M/990M [00:03<00:00, 255MB/s]
# model.safetensors:   0%|                             | 0.00/990M [00:00<?, ?B/s]Loading Translation model (VietAI EnViT5)...
#
# tokenizer_config.json: 1.19kB [00:00, 524kB/s]
#
# model.safetensors:  16%|███▌                  | 163M/990M [00:01<00:04, 167MB/s]
# spiece.model: 100%|████████████████████████| 1.10M/1.10M [00:00<00:00, 3.21MB/s]
# model.safetensors:  32%|███████               | 319M/990M [00:01<00:02, 261MB/s]
# tokenizer.json: 3.49MB [00:00, 51.4MB/s]
#
# special_tokens_map.json: 1.11kB [00:00, 4.61MB/s]
# model.safetensors:  46%|██████████            | 453M/990M [00:02<00:02, 227MB/s]
# config.json: 100%|█████████████████████████████| 721/721 [00:00<00:00, 5.93MB/s]
# model.safetensors:  73%|████████████████      | 721M/990M [00:02<00:00, 485MB/s]
# model.safetensors: 100%|██████████████████████| 990M/990M [00:02<00:00, 377MB/s]
#
# pytorch_model.bin:   0%|                    | 759k/1.10G [00:00<15:48, 1.16MB/s]
# pytorch_model.bin:   6%|█▏                 | 67.8M/1.10G [00:01<00:17, 59.2MB/s]
# pytorch_model.bin:  12%|██▌                  | 135M/1.10G [00:01<00:08, 111MB/s]
# pytorch_model.bin:  21%|████▎                | 229M/1.10G [00:01<00:04, 198MB/s]
# pytorch_model.bin:  27%|█████▋               | 296M/1.10G [00:02<00:04, 189MB/s]
# pytorch_model.bin:  39%|████████▏            | 430M/1.10G [00:02<00:02, 325MB/s]
# pytorch_model.bin:  51%|██████████▊          | 564M/1.10G [00:02<00:01, 466MB/s]
# pytorch_model.bin:  70%|██████████████▌      | 765M/1.10G [00:02<00:00, 669MB/s]
# pytorch_model.bin:  82%|█████████████████▏   | 899M/1.10G [00:02<00:00, 746MB/s]
# pytorch_model.bin: 100%|████████████████████| 1.10G/1.10G [00:02<00:00, 400MB/s]
# model.safetensors:  88%|██████████████████▍  | 966M/1.10G [00:03<00:00, 731MB/s]
# model.safetensors: 100%|████████████████████| 1.10G/1.10G [00:03<00:00, 284MB/s]
# image_13626_4.png: Một bồn rửa mặt màu trắng trong phòng tắm cạnh bồn cầu
# image_26378_6.png: một người đứng trước cửa sổ trong một căn phòng tối
# image_26798_0.png: Một người đang bơi trong hồ bơi với cảnh hoàng hôn ở phía sau
# image_3785_0.png: góc nhìn toà nhà từ trên đỉnh toà nhà
# image_4089_1.png: Một người phụ nữ đứng trước một tòa nhà với những bông hoa màu tím
# image_28812_0.png: một hồ bơi trống trong một tòa nhà
# image_18113_2.png: nhìn ra đại dương từ cửa sổ
# image_22045_2.png: Một cây cọ trên bãi biển với đại dương ở phía sau
# image_10828_0.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_26083_2.png: một phòng tắm nhìn ra biển
# image_6836_0.png: Một người phụ nữ ngồi bên cạnh bể bơi với những cây cọ ở phía sau
# image_19750_1.png: Một phòng khách sạn có giường, bàn và ghế
# image_28359_0.png: Một cái kệ có sơn trên đó.
# image_23160_0.png: một cảnh trên không của một khu nghỉ mát có bể bơi
# image_4715_5.png: Một cái thang gỗ có vài cái cây trong đó
# image_17254_4.png: hai bát thức ăn đặt trên bếp lò
# image_27753_2.png: một cái bàn với thức ăn trên đó trước một bức tường đá cẩm thạch
# image_18702_0.png: nhìn ra bãi biển từ ban công vào ban đêm
# image_14942_1.png: Nhìn từ ban công của ngôi nhà bãi biển
# image_15301_1.png: Bàn ghế trong nhà hàng có tường gạch
# image_26328_2.png: Một người phụ nữ đứng trước quầy trong một nhà hàng
# image_26377_2.png: Một hồ bơi với ghế dài và nhìn ra biển
# image_5617_2.png: Một nhà hàng với nhiều bàn ghế trong đó
# image_2149_1.png: Một người phụ nữ đứng trước khách sạn
# image_5602_2.png: Một nhóm người trong bếp chuẩn bị thức ăn
# image_19787_0.png: nhìn ra bãi biển từ trên đỉnh của một toà nhà
# image_7742_0.png: Một phòng khách với tường màu xanh và sàn màu đen và trắng
# image_16326_3.png: - Một tủ lớn bằng gỗ có tay cầm màu đen và tay cầm màu đen.
# image_18398_1.png: Một người phụ nữ đứng bên bờ hồ bơi
# image_15695_3.png: Một phụ nữ mặc váy xanh lá cây ngồi trên một sàn gỗ
# image_27327_0.png: một bàn cà phê với đồ ăn nhẹ và đồ uống trên đó
# image_16008_0.png: Một cặp người đứng trước một tòa nhà
#
# Generating Captions:   0%|                      | 1/573 [00:04<45:45,  4.80s/it]image_23632_2.png: Một bức tượng trước khách sạn vào ban đêm
# image_25400_0.png: Một cái cây nhỏ ở giữa sân
# image_4753_0.png: Một bộ bốn chiếc ghế gỗ ngồi trên một sàn lát gạch
# image_23303_1.png: Một bàn đầy thức ăn trên bãi biển lúc hoàng hôn
# image_22729_6.png: Một nhóm người ngồi tại một chiếc bàn trên bãi biển
# image_5767_5.png: - một ban công nhìn ra biển và núi non. '
# image_20267_2.png: phòng tắm có bồn rửa mặt và gương
# image_27114_2.png: Hai ly rượu ngồi trên một cái bàn cạnh biển.
# image_14710_2.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_28303_0.png: Một người phụ nữ mặc váy đen đứng trên một cây cầu gỗ với những cây cọ ở phía sau
# image_5722_1.png: Một đĩa thức ăn trên bàn trong nhà hàng
# image_27650_0.png: khung cảnh thành phố từ cửa sổ
# image_20433_0.png: Cảnh bãi biển từ trên cao lúc hoàng hôn
# image_15676_3.png: - một hồ bơi được bao quanh bởi cây cối và cây cối. '
# image_5253_2.png: Hai giường trong một phòng khách sạn nhìn ra thành phố
# image_18674_3.png: Một hồ bơi nhìn ra biển
# image_4418_0.png: Một người đàn ông đang chụp ảnh mình trong gương
# image_6273_0.png: Một nhóm người đứng quanh một cái bàn với thức ăn trên đó
# image_15176_1.png: Một phòng khách sạn với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_21527_4.png: Hai ly sôcôla và hoa đặt trên bàn.
# image_21969_1.png: Một hồ bơi với những cây cọ bao quanh
# image_23041_1.png: Một người đàn ông và một người phụ nữ đứng trước một khách sạn
# image_3810_1.png: một căn phòng với giường và ti vi trên tường
# image_17823_0.png: Quang cảnh đại dương từ máy bay
# image_5076_4.png: Trước khách sạn với một chiếc xe đậu trước mặt.
# image_9974_0.png: một hồ bơi trong nhà được bao quanh bởi các loài thực vật nhiệt đới
# image_18420_2.png: một người phụ nữ ngồi ăn tại bàn
# image_28307_3.png: Một người đàn ông đứng trên vỉa hè cạnh một cái cây
# image_24481_0.png: một căn phòng với giường, bàn và ti vi
# image_4389_0.png: Hai người nằm trên giường.
# image_23609_0.png: chân của một người trên boong tàu có thể nhìn ra biển
# image_24230_3.png: một phòng ngủ với giường và quạt trần
#
# Generating Captions:   0%|                      | 2/573 [00:08<38:52,  4.08s/it]image_27001_3.png: Một toà nhà cao với nhiều cửa sổ và nền trời
# image_20382_0.png: một người ngồi trên giường trước cửa sổ
# image_12106_0.png: một cái bàn gỗ với bát thức ăn ở trên
# image_30980_0.png: Một người phụ nữ đứng trước một tấm biển ở quầy
# image_3636_0.png: Một tòa nhà màu trắng với tấm biển đề khách sạn paris
# image_22113_0.png: Một người đàn ông đứng trước bể bơi
# image_14205_5.png: Quang cảnh từ mái của một toà nhà ở bangkok, thái lan
# image_24073_0.png: một phòng khách sạn với giường, bàn, ghế và ti vi
# image_26101_0.png: Lối vào khách sạn vào ban đêm
# image_20528_0.png: chân của một người trước bể bơi
# image_6322_0.png: Một nhóm người tập thể dục trong phòng tập
# image_24907_0.png: Một cái giường với khăn trải giường trắng và hoa đỏ trên đó
# image_16201_0.png: Một căn phòng nhỏ với những cái tủ trắng và một cái túi đen trên sàn.
# image_5476_1.png: Hai người trong hồ bơi với đại dương ở phía sau
# image_19779_1.png: một căn phòng với một chiếc tivi, tủ lạnh và tủ lạnh
# image_10939_1.png: Một cái ví hồng đặt trên bàn
# image_16358_1.png: Một người phụ nữ ngồi bên cạnh hồ bơi
# image_25514_4.png: nhìn ra bãi biển và núi từ ban công
# image_10360_4.png: Một hành lang với một băng ghế màu xanh và một bức tranh trên tường
# image_5867_1.png: Một người đàn ông bế một bé gái trước cửa sổ
# image_24184_4.png: Một hồ bơi với những cây cọ bao quanh
# image_15080_0.png: một cái ao trước một toà nhà vào ban đêm
# image_26117_0.png: Một căn phòng có giường và bàn làm việc
# image_1655_4.png: Quang cảnh từ mái nhà của một ngôi nhà ở singapore
# image_24953_3.png: Toà nhà được thắp sáng vào ban đêm.
# image_18754_2.png: Một nhóm người đứng trước quầy tiếp tân
# image_23122_2.png: - một cái bàn có những đĩa thức ăn và đồ uống trên đó. '
# image_8452_0.png: Một nhóm người đứng trong sảnh
# image_31445_2.png: - Cửa phòng tắm bằng kính
# image_98_3.png: Một con mèo đen trắng ngồi bên vệ đường
# image_18473_1.png: Một chiếc đĩa trắng phủ bánh sinh nhật phủ sô cô la
# image_11726_1.png: Một căn phòng với một cửa sổ lớn và một TV trên tường
#
# Generating Captions:   1%|                      | 3/573 [00:12<37:25,  3.94s/it]image_32702_0.png: một chiếc giường nằm trong phòng ngủ cạnh cửa sổ
# image_8992_1.png: Một khay thức ăn trên bàn
# image_8774_2.png: Quang cảnh thành phố vào ban đêm từ đỉnh của một toà nhà
# image_27_4.png: một vườn hoa trước một toà nhà
# image_1049_1.png: Một cánh đồng đầy cây xanh với bầu trời đầy mây làm nền
# image_26882_3.png: một phòng ngủ với giường, bàn làm việc và gương
# image_26121_3.png: Quang cảnh thành phố từ đỉnh của một toà nhà
# image_28408_2.png: Một tòa nhà với một đám cây cối ở phía trước
# image_3084_2.png: một cửa sổ với tầm nhìn ra một cái cây bên ngoài
# image_16741_1.png: một ngôi nhà với một ngọn núi ở phía sau
# image_19458_4.png: Một người phụ nữ trong chiếc áo choàng tắm nằm trên sân trong
# image_18261_0.png: nhìn ra bãi biển từ trên đỉnh của một toà nhà
# image_26344_1.png: sân trong đêm
# image_8220_1.png: một phòng ngủ với một cái giường và một bức tranh trên tường
# image_17285_1.png: Một người phụ nữ mặc váy xanh đi bộ qua một khu vườn
# image_7540_1.png: cảnh cây cầu bắc qua sông vào ban đêm
# image_10242_0.png: Một cái ván trượt đang nằm trên sàn.
# image_5602_4.png: Một dãy ghế dài trước một cửa sổ lớn
# image_27106_2.png: Trăng tròn chiếu sáng bầu trời trên đại dương
# image_27754_0.png: Một đám xe hơi đậu trong bãi đỗ xe ban đêm
# image_5499_0.png: Một bình hoa đặt trên bàn gỗ
# image_211_1.png: Một hành lang dài với những bức tranh trên tường
# image_3561_0.png: một phòng ngủ với một chiếc giường trắng và một tấm gương
# image_3403_6.png: một cái đèn đặt trên bàn
# image_24339_1.png: một phòng ngủ với một cái giường và một cánh cửa trượt
# image_10557_2.png: Một tòa nhà cao tầng giữa lòng thành phố
# image_9460_1.png: Quang cảnh thành phố vào ban đêm từ mái của một toà nhà
# image_16357_2.png: một phòng ngủ với một cái giường và một cái ghế
# image_23162_0.png: một thảm cỏ với cây cọ và một ngôi nhà ở phía sau
# image_4170_0.png: trước một nhà hàng với rất nhiều cây cối và hoa
# image_2002_0.png: Một cái bàn có ít thức ăn trên đó
# image_1611_0.png: một vài chiếc giường trong phòng ngủ cạnh cửa sổ
#
# Generating Captions:   1%|▏                     | 4/573 [00:15<35:26,  3.74s/it]image_13861_2.png: Một người đàn ông đang sơn tường bằng sơn trắng
# image_24953_4.png: một cái đĩa trắng phủ thịt, để cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho
# image_1227_0.png: một cửa sổ với mưa trên đó
# image_24975_4.png: Một cái bàn với những đĩa thức ăn trên đó
# image_28524_0.png: Một cái đĩa có một tách trà trên đó.
# image_27465_3.png: nhìn ra đại dương từ mái của một toà nhà
# image_21394_4.png: Một phòng khách với một chiếc ghế dài và một chiếc ghế dài
# image_14933_0.png: một cái giường với một cái đèn trên đầu giường
# image_3824_2.png: phòng tắm có bồn rửa mặt và vòi hoa sen
# image_2561_0.png: Một căn phòng nhỏ với một cái bàn và một cái ti vi.
# image_27757_0.png: một phòng khách nhìn ra biển
# image_19247_1.png: Một phòng khách sạn có giường, bàn và ghế
# image_10220_0.png: một phòng tắm có bồn rửa mặt và gương trong đó
# image_15644_0.png: một phòng ngủ với giường, ghế và cửa trượt bằng kính
# image_23798_2.png: một ngôi nhà có bể bơi ở sân sau
# image_26986_6.png: Một căn phòng rộng với rất nhiều bàn ghế.
# image_21228_0.png: cảnh hồ bơi vào ban đêm
# image_6373_6.png: góc nhìn thành phố từ trên đỉnh toà nhà
# image_18484_0.png: Một người phụ nữ ngồi trên một cái phao ở hồ bơi
# image_14998_4.png: Một nhà hàng với tường xanh và trần trắng
# image_16137_0.png: phòng tắm với bồn tắm và cửa sổ
# image_26111_0.png: Một chiếc giường trong một phòng khách sạn với một bức tranh trên tường
# image_6155_2.png: Một vùng nước rộng lớn
# image_15247_0.png: một phòng ngủ với một cái giường và một cánh cửa trượt
# image_27158_0.png: Hồ bơi trên đỉnh núi.
# image_23304_3.png: Một phụ nữ đội nón ngồi tại bàn trên bãi biển
# image_24735_3.png: Một người đàn ông ngồi trên ghế trước mặt biển lúc hoàng hôn
# image_18426_1.png: một người nằm trên cát trên bãi biển
# image_9119_1.png: một hình gần một chiếc giường với một tấm trắng trên đó
# image_20383_0.png: một chồng đá nằm trên một tảng đá
# image_5100_0.png: Một nhóm người đứng cạnh một đoàn tàu
# image_15001_1.png: Hồ bơi ở phía trước khách sạn.
#
# Generating Captions:   1%|▏                     | 5/573 [00:21<44:13,  4.67s/it]image_20749_0.png: Một người phụ nữ ẵm một đứa bé trong tay
# image_32205_1.png: Một người phụ nữ ngồi trên ghế cạnh một bức tượng
# image_14812_5.png: Một cái nhìn từ mái nhà ở một khu vực nông thôn với cây cọ và nhà ở phía sau
# image_1039_0.png: Một người phụ nữ ngồi trên ghế trước cửa sổ
# image_10352_1.png: Một căn phòng với một cái giường và một cái ghế
# image_29140_1.png: Một phòng khách sạn có giường và ghế
# image_23445_3.png: một phòng ngủ với một cái giường và một bức tranh trên tường
# image_22699_0.png: Một cửa sổ lớn với rèm cửa và đèn chùm
# image_1055_0.png: Một phòng khách đầy đồ đạc
# image_19189_1.png: Một đứa bé đang đứng trên giường trước tivi
# image_10301_2.png: một cái bàn với bát thức ăn và bát súp
# image_2186_0.png: một chiếc giường với một bồn tắm trước cửa sổ
# image_28960_1.png: Một chiếc xe đỗ trước một ngôi nhà
# image_10049_0.png: một căn bếp nhỏ với một bồn rửa và lò vi sóng
# image_21059_0.png: Quang cảnh thành phố vào ban đêm từ đỉnh đồi
# image_567_0.png: một cái bồn cầu trắng đặt cạnh một cái bồn rửa mặt trắng
# image_25401_0.png: Một khu vườn với rất nhiều cây cối
# image_14655_1.png: một cặp giường đôi trong phòng
# image_16954_0.png: Một người cầm hai túi thức ăn trên tay
# image_7805_5.png: Quang cảnh từ tầng trên cùng của khách sạn vào ban đêm
# image_23316_4.png: Một chiếc thuyền nhỏ trôi nổi trên mặt nước
# image_30945_5.png: góc nhìn thành phố từ trên đỉnh toà nhà
# image_3137_1.png: phòng tắm có bồn rửa mặt, nhà vệ sinh và vòi hoa sen
# image_8763_6.png: Một bữa tiệc buffet với rất nhiều loại thức ăn khác nhau
# image_5515_2.png: Một phòng khách sạn hai giường và một ghế dài.
# image_18566_0.png: một phòng khách sạn với giường, bàn và ti vi
# image_27308_0.png: một con mèo nằm trên giường cạnh một cái cây
# image_17345_1.png: Một căn phòng có vài tấm rèm treo trên trần nhà
# image_28437_4.png: một hồ bơi trống giữa sa mạc
# image_32385_0.png: Một người đàn ông ngồi tại bàn với một buồng giam trong tay
# image_15789_2.png: Một hồ bơi lớn trước một toà nhà màu trắng
# image_28408_0.png: một cái đèn treo trên trần nhà
#
# Generating Captions:   1%|▏                     | 6/573 [00:25<41:14,  4.36s/it]image_17824_0.png: Một phòng khách sạn với một chiếc giường lớn và một chiếc ti vi
# image_2002_1.png: - một cái bàn gỗ để picnic. '
# image_26684_1.png: Một người phụ nữ đứng trên nóc một tòa nhà bên cạnh biển
# image_10143_5.png: Một căn bếp với những cái tủ màu trắng và một cái bếp lò
# image_16141_0.png: Bàn tiếp tân của một khách sạn với những người đứng trước nó
# image_20234_1.png: một chiếc giường với chăn bông trắng trong phòng khách sạn
# image_11757_3.png: một chiếc giường với chăn bông và gối trắng
# image_12606_1.png: Một bồn tắm màu trắng bên cạnh cửa sổ
# image_26793_0.png: Hai người đang nướng cocktail trước bể bơi
# image_18109_0.png: Một cái bàn với ba đĩa thức ăn trên đó.
# image_91_4.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_24735_4.png: Mặt trời đang lặn trên đại dương và cây cọ
# image_33328_6.png: Một con mèo đen trắng ngồi trên nóc tủ lạnh
# image_2395_0.png: TV màn hình phẳng gắn trên tường
# image_26883_0.png: một cánh cửa mở trong một căn phòng với một cái cây trên sàn nhà
# image_1384_2.png: Một căn phòng có giường và gương trong đó
# image_21795_1.png: nhìn ra đại dương từ bãi biển
# image_27477_0.png: Quang cảnh thành phố từ cửa sổ của một toà nhà
# image_23172_1.png: - một cái giường có hai con thiên nga làm bằng khăn tắm nằm trên. '
# image_26070_4.png: nhìn ra bãi biển và đại dương từ bể bơi
# image_22732_0.png: Một người phụ nữ ngồi tại bàn trên bãi biển
# image_21189_0.png: một ban công nhìn ra biển
# image_14579_1.png: Một phòng khách sạn có giường và bàn làm việc
# image_16588_0.png: một phòng ngủ với một chiếc giường lớn và một chiếc quạt trần
# image_1655_5.png: Nhìn từ mái nhà của một ngôi nhà trong khu dân cư
# image_6325_0.png: nhìn ra bãi biển và đại dương từ ban công
# image_4335_6.png: Bên trong một nhà hàng với những bức tường màu xanh và những chiếc ghế màu vàng
# image_22291_1.png: một vài chiếc giường nằm trên một sàn gỗ
# image_28415_3.png: một cái bàn có khăn trải bàn màu xanh lá cây
# image_19442_0.png: một phòng ngủ với một cái giường và một bức tranh trên tường
# image_32087_5.png: nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc nấm mốc
# image_28599_0.png: Một nhà hàng với bàn ghế nhìn ra biển
#
# Generating Captions:   1%|▎                     | 7/573 [00:33<51:37,  5.47s/it]image_22693_1.png: Một người đàn ông đứng trước bể bơi
# image_15547_0.png: Một phòng khách sạn có giường và bàn làm việc
# image_15414_0.png: một phòng ngủ với một chiếc giường lớn và cửa trượt bằng kính
# image_28276_4.png: Một người phụ nữ ngồi trên ghế trước một cây cọ
# image_11588_0.png: khung cảnh thành phố vào ban đêm từ cửa sổ
# image_24852_0.png: Một căn phòng với hai giường và một tấm gương trên tường
# image_13626_5.png: hình một lỗ trên trần nhà
# image_908_0.png: hai giường trong một phòng khách sạn
# image_20734_4.png: - Khu vực ăn uống ngoài trời có bàn và ô che nắng.
# image_9834_0.png: Một ngăn kéo với đồ bạc và đồ bạc trong đó
# image_28719_1.png: Một nhà vệ sinh màu trắng bên cạnh một phòng tắm
# image_30962_0.png: Một người phụ nữ ngồi trên ghế trước gương
# image_31395_2.png: một phòng khách với một chiếc ghế dài và một bàn cà phê
# image_3561_2.png: một phòng ngủ có giường và cửa sổ có rèm
# image_19604_4.png: một ban công nhìn ra biển
# image_3965_4.png: Cảnh thành phố từ cửa sổ tàu hoả
# image_2153_0.png: một cái nhìn ra hồ qua những tán cây
# image_5833_0.png: hai người phụ nữ đứng cạnh nhau phụ nữ
# image_17141_3.png: Một cái bồn rửa mặt màu trắng đặt trên một cái kệ gỗ
# image_10827_1.png: Một chiếc giường trong một phòng khách sạn với những bức tường màu đỏ
# image_14278_0.png: Một người đi xe máy xuống đường vào ban đêm
# image_1065_3.png: Một ngôi nhà trên một ngọn đồi với những cái cây ở phía sau
# image_16355_3.png: Một sàn gỗ cạnh bể bơi
# image_22720_1.png: Một nhóm trẻ em chơi trong hồ bơi
# image_27100_0.png: góc nhìn phòng khách qua cửa sổ
# image_21340_1.png: Hai cái ô lợp mái trên mặt nước.
# image_15241_3.png: một tấm gương trên tường
# image_30440_3.png: một chiếc giường trong một căn phòng nhìn ra thành phố
# image_844_0.png: Một con mèo ngồi trên một chiếc ghế gỗ
# image_29470_0.png: một phòng khách với quạt trần và ghế dài
# image_2004_1.png: một cái sân với một cái bàn và ghế ở giữa
# image_18629_0.png: Mặt trời đang lặn trên đại dương và cây cọ
#
# Generating Captions:   1%|▎                     | 8/573 [00:36<44:53,  4.77s/it]image_28006_0.png: Một cảnh quan của một thành phố với các toà nhà và một vùng nước
# image_32320_0.png: Mặt trời đang lặn trên bầu trời, trên bãi đậu xe.
# image_9492_3.png: một phòng ăn với một bàn và ghế
# image_5512_0.png: Hai giường trong một phòng khách sạn nhìn ra biển.
# image_18468_4.png: Căn hộ 2 phòng ngủ cho thuê trong Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju Ju
# image_17689_1.png: phòng khách sạn có giường lớn và ghế ngồi
# image_10937_2.png: một cái bồn cầu màu trắng đặt cạnh bồn tắm
# image_20072_0.png: một cái giường trong một căn phòng với những bức tường màu hồng
# image_26789_2.png: Một người phụ nữ ngồi trên ghế trước một tòa nhà
# image_7187_1.png: Một tòa nhà với cây cối mọc bên cạnh
# image_4957_0.png: Một căn phòng trang trí bằng vàng và hồng.
# image_6157_0.png: Một phụ nữ ngồi trong bồn tắm nhìn ra cửa sổ
# image_21684_1.png: Một nhóm người đứng trên bãi biển cạnh đại dương
# image_23596_1.png: một cái đĩa trắng với salad và nước sốt
# image_24433_0.png: Một nhóm người ngồi quanh một cái bàn trong một căn phòng
# image_2511_3.png: Một người đàn ông ngồi tại bàn với một tách cà phê
# image_13927_2.png: một phòng ngủ với giường và quạt trần
# image_33300_4.png: Sàn nhà trong góc phòng có lỗ thủng trên đó
# image_31853_1.png: phòng tắm có bồn cầu, bồn rửa mặt và bồn tắm
# image_28563_0.png: Một nhà vệ sinh màu trắng bên cạnh một phòng tắm
# image_15675_1.png: một ban công với cây cối và cây cối trên đó
# image_22472_0.png: Cảnh trên không của một bãi biển với những chiếc thuyền trên mặt nước
# image_23062_4.png: Một người đàn ông và một người phụ nữ đứng trên bãi biển cạnh nhau
# image_18680_0.png: Một cô bé đứng trước cửa sổ
# image_7840_2.png: Một nhóm người ngồi tại một bàn trong một nhà hàng
# image_26088_0.png: Mọi người đang ngồi trong sảnh của một tòa nhà văn phòng
# image_30964_0.png: 2 người phụ nữ chụp ảnh tự sướng tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự tự
# image_1998_0.png: Một người đàn ông chụp ảnh một người phụ nữ trước gương
# image_21271_0.png: Một người phụ nữ ngồi trên một tảng đá trước mặt đại dương lúc hoàng hôn
# image_18466_0.png: Quang cảnh thành phố vào ban đêm từ đỉnh đồi
# image_27458_0.png: nhìn ra đại dương từ cửa sổ
# image_19350_0.png: Một phòng khách sạn với một chiếc giường và một tấm gương lớn
#
# Generating Captions:   2%|▎                   | 9/573 [00:49<1:08:59,  7.34s/it]image_27529_0.png: Một người đàn ông và một người phụ nữ đứng trước một tòa nhà
# image_580_0.png: Một phòng khách với cây thông noel và đèn chùm
# image_22957_3.png: nhìn ra mặt nước từ cửa sổ nhà hàng
# image_7053_2.png: một cái nhìn ra đại dương từ một boong tàu
# image_25534_3.png: nhìn ra đại dương từ phòng khách sạn
# image_27088_0.png: Một phòng khách sạn có giường và rèm cửa
# image_28910_3.png: một vài cái ghế đẩu dưới một cái ô
# image_4132_0.png: Một góc nhìn từ mái nhà của một ngôi nhà ở Philippines
# image_23175_0.png: một bể bơi lớn trước khách sạn
# image_3034_0.png: một người nằm trên giường trong phòng
# image_6158_0.png: Một căn phòng nhìn ra biển
# image_23798_3.png: một bãi cỏ với ghế và bàn trước một ngôi nhà
# image_30987_0.png: Một người phụ nữ đứng trước gương trong phòng
# image_28405_1.png: Một người đàn ông đứng trước một tòa nhà với một quả bóng bay
# image_29529_1.png: một bàn tay chỉ vào giường trong phòng khách sạn
# image_21427_1.png: Một người phụ nữ ngồi trên ghế trước cửa sổ
# image_6144_0.png: Quang cảnh thành phố từ phòng khách
# image_18397_0.png: nhìn ra bể bơi và bãi biển từ ban công của khu nghỉ mát
# image_8163_1.png: Một hồ bơi với những cây cọ bao quanh
# image_22506_2.png: một phòng khách nhìn ra biển
# image_411_0.png: Một phụ nữ đeo khẩu trang và xách một va li màu đỏ
# image_28317_2.png: Một phụ nữ mặc váy đỏ đứng trên ban công
# image_15212_0.png: Một người đàn ông ngồi bên cạnh hồ bơi
# image_11984_2.png: Một căn phòng trống với một cửa sổ lớn và tấm thảm màu vàng
# image_5077_1.png: Một phòng khách với hai ghế dài và một bình cà phê trên bàn
# image_28916_0.png: Một bình hoa trắng vàng
# image_22709_0.png: Một tảng đá lớn ở giữa một vùng nước
# image_33581_1.png: một phòng ngủ với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_12785_0.png: một căn phòng với giường, bàn và ti vi
# image_27480_0.png: một cái nhìn ra hồ bơi từ ban công
# image_18347_0.png: một cái nhìn từ trên không của khu nghỉ mát với đại dương trong nền
# image_19216_0.png: Một hồ bơi với những cây cọ bao quanh
#
# Generating Captions:   2%|▎                    | 10/573 [00:53<57:16,  6.10s/it]image_20034_1.png: Một góc nhìn của một toà nhà lớn từ cửa sổ
# image_27102_1.png: Cảnh khách sạn từ bãi biển
# image_7460_1.png: Một người phụ nữ đứng trước một bức tường có hình ảnh trên đó
# image_13248_1.png: Một con mèo ngồi trên bàn cạnh một cái túi
# image_17899_0.png: Một người đàn ông ngồi trên ghế trước cửa sổ
# image_18255_0.png: Quang cảnh mặt trời lặn trên đại dương
# image_24975_3.png: Một người phụ nữ ngồi trước một chiếc đàn piano trước một cửa sổ lớn
# image_16351_1.png: Một nhóm người đứng trước một tòa nhà màu đỏ
# image_1555_1.png: 3 nhà ngủ và lô đất để bán tại cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu
# image_19135_4.png: Một nhóm trẻ em chơi dưới nước
# image_361_1.png: một cảnh thành phố từ ban công
# image_24230_5.png: Hai chiếc ghế dài trên bãi biển với những cây cọ làm nền
# image_19247_3.png: một chiếc giường với ga trải giường và gối trắng trong phòng khách sạn
# image_23931_2.png: mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac mac
# image_21272_0.png: Một người phụ nữ đứng trên ban công nhìn ra biển
# image_2313_1.png: một phòng khách sạn nhìn ra thành phố
# image_5625_4.png: Một đĩa thức ăn trên bàn cạnh một ly nước cam
# image_10752_0.png: Một người đàn ông và một cậu bé nằm trên giường
# image_22335_0.png: Hai người đi bộ trên bãi biển trước mặt đại dương
# image_9750_0.png: Một phòng ngủ với một cái giường và một cửa sổ lớn
# image_23686_0.png: chân của một người trong một hồ bơi với cây cọ ở phía sau
# image_15579_1.png: Một cái bàn gỗ với những đĩa thức ăn trên đầu
# image_23421_4.png: Một nhóm búp bê nhồi bông trên bàn với những người ở phía sau
# image_18648_4.png: một người ngồi tại bàn trước cửa sổ
# image_25327_2.png: Một căn phòng với một cái bàn và một cái ti vi trên tường.
# image_5482_0.png: Một phòng khách sạn với một chiếc giường lớn và rèm cửa màu xanh
# image_15631_3.png: Một người phụ nữ đứng trên cầu thang của một ngôi nhà
# image_19879_0.png: một người đang cầm một tách cà phê
# image_18646_3.png: Một người đứng trên cầu tàu nhìn ra biển
# image_27378_1.png: hai cái bánh ngọt trên một cái đĩa trắng có một cái ô màu xanh ở sau
# image_23114_1.png: Một người phụ nữ cầm ván trượt trên bãi biển
# image_5605_2.png: Một cái bàn với những đĩa thức ăn trên đó
#
# Generating Captions:   2%|▍                    | 11/573 [00:59<56:58,  6.08s/it]image_17037_0.png: Bán 3 phòng ngủ trong nhà phố ở Quezon
# image_14811_0.png: - một bể bơi được bao quanh bởi những cây cọ và ô dù. '
# image_14248_0.png: Chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều chiều
# image_26983_0.png: Một hành lang dài với ánh sáng trên trần nhà
# image_21873_0.png: Một người đàn ông ngồi tại bàn với một đĩa thức ăn
# image_27657_3.png: Một cái bát trắng đựng đầy thức ăn trên bàn
# image_21165_1.png: một quán bar với ghế gỗ và kệ trên tường
# image_16595_4.png: Một cái bàn với một tô trái cây trên đó
# image_31624_0.png: một phòng khách sạn có bồn tắm và giường
# image_2008_0.png: Quang cảnh từ đỉnh đồi
# image_28273_3.png: một tách cà phê trên bàn nhìn ra biển
# image_21811_2.png: Một đĩa cua đầy trên bàn
# image_23904_4.png: một bồn tắm đá ở giữa phòng
# image_2386_1.png: một người ngồi trên giường trong phòng
# image_12312_3.png: Một căn phòng có hai cửa và một cửa sổ
# image_23428_1.png: nhìn ra đại dương từ ban công của một ngôi nhà bãi biển
# image_14070_0.png: Một nhóm người đi bộ trên đường phố trong công viên
# image_7233_0.png: một chiếc giường trong khách sạn có tầm nhìn ra thành phố
# image_21897_0.png: Một đĩa thức ăn trên bàn gỗ
# image_18647_6.png: Một chiếc đĩa trắng phủ thịt gà rán trên bàn gỗ
# image_23714_0.png: Một bãi biển với những chiếc thuyền và cây cọ làm nền
# image_27160_4.png: một chiếc giường có gối và gối trong phòng
# image_10550_0.png: Một phòng khách với màn hình phẳng trên tường
# image_20209_0.png: một cảnh nhìn ra một vùng nước từ mái nhà
# image_23375_3.png: một phòng ngủ với một bức tường đá và một cánh cửa gỗ
# image_26664_1.png: Một phòng khách đầy đồ đạc và một bàn ăn
# image_28393_0.png: Một người đàn ông trong hồ bơi đầu vùi trong nước
# image_31996_0.png: Một căn phòng có cửa và một tấm biển trên tường
# image_15318_4.png: phòng tắm với bồn tắm và bồn rửa mặt
# image_567_2.png: một phòng tắm có vòi sen và nhà vệ sinh bên trong
# image_22827_1.png: Một nhóm người ngồi trong sảnh
# image_24091_0.png: Một người phụ nữ ngồi trên ban công nhìn ra biển
#
# Generating Captions:   2%|▍                    | 12/573 [01:03<52:23,  5.60s/it]image_266_0.png: Một nhóm người ngồi tại một bàn trong một nhà hàng
# image_24825_1.png: một sàn gỗ với những đường kẻ trắng trên đó
# image_16778_1.png: Hồ bơi ở phía trước khách sạn.
# image_15235_3.png: chân của một người trước bể bơi
# image_8268_0.png: Một phòng khách với một chiếc ghế dài và một cửa sổ
# image_18771_3.png: Một bó hoa trưng bày trong một căn phòng
# image_3312_1.png: Một con mèo đen trắng ngồi trên bồn cầu
# image_166_0.png: máy pha cà phê đen
# image_3170_0.png: Một ngôi nhà màu xanh với một chiếc xe màu trắng đậu trước mặt nó
# image_19833_1.png: một cái nhìn của hồ bơi và các toà nhà xung quanh
# image_9837_1.png: một căn bếp với một bồn rửa và lò vi sóng
# image_28835_2.png: Một phòng khách sạn nhìn ra thành phố
# image_29024_0.png: Một chiếc giường trong một phòng khách sạn với ga trải giường và gối trắng
# image_22521_1.png: một ban công nhìn ra biển
# image_21838_0.png: hai giường trong một phòng khách sạn
# image_9658_4.png: Một cái bàn có bát đựng thức ăn
# image_17373_1.png: Một căn phòng có giường và cửa
# image_1277_0.png: Một phòng khách với sàn lát gạch màu đen và trắng
# image_15291_1.png: một phòng ngủ với một bồn tắm và một cái giường
# image_21287_0.png: một hồ nước với mái lợp rơm cạnh vài cây cọ
# image_23639_1.png: một bãi cỏ xanh với ghế trắng và cây cọ ở phía sau
# image_24119_0.png: Một người đàn ông đứng trên ban công của một tòa nhà
# image_22718_0.png: Một người phụ nữ mặc váy hồng đứng trước bể bơi
# image_22822_0.png: Một chiếc ghế dài màu nâu lớn ngồi trên sàn đá cẩm thạch.
# image_21979_0.png: nhìn ra đại dương từ một nhà hàng trên bãi biển
# image_18845_2.png: Một chiếc tivi màn hình phẳng đặt trên một chiếc bàn trang điểm màu trắng
# image_22817_0.png: Một người đàn ông đứng trên nóc một tòa nhà cạnh một hồ bơi
# image_2_1.png: Một bãi đậu xe với những chiếc xe đỗ trong đó
# image_30550_0.png: Một bức tường màu đen và vàng với một khung hình trên đó
# image_21082_0.png: Một căn phòng với một cái giường và một cái đồng hồ treo tường.
# image_22531_0.png: một phòng ngủ với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_17993_0.png: Mặt trời lặn trên đại dương với những cây cọ ở phía trước
#
# Generating Captions:   2%|▍                    | 13/573 [01:07<47:09,  5.05s/it]image_5868_0.png: Quang cảnh thành phố vào ban đêm từ một ngọn đồi
# image_31480_3.png: nhìn ra đại dương từ ban công
# image_27167_0.png: một bầu trời trong xanh
# image_13707_0.png: Một bức tường trắng với một chiếc đồng hồ trên đó
# image_32922_0.png: một căn bếp với bếp, bồn rửa và lò nướng
# image_7977_1.png: một người đang cầm bánh sinh nhật trên bàn
# image_14121_4.png: một cửa sổ có rèm cửa và một tầm nhìn ra thành phố
# image_17665_2.png: phòng tắm có vòi hoa sen, bồn rửa mặt và gương
# image_15342_1.png: một khoảng sân nhỏ với sàn lát gạch và chậu cây
# image_20185_0.png: nhìn ra biển từ ban công của một toà nhà
# image_18674_4.png: một cái nhìn ra bãi biển và đại dương từ trên đỉnh của một toà nhà
# image_28306_0.png: Một phụ nữ mặc váy vàng ngồi trên ghế dài trắng
# image_23151_0.png: Một người đàn ông và một người phụ nữ đứng trước bàn tiếp tân
# image_22017_0.png: một hồ bơi ban đêm với đèn sáng
# image_32046_2.png: Nội thất của một nhà hàng với một quầy bar và ghế
# image_27369_3.png: Một người phụ nữ ngồi bên cạnh hồ bơi
# image_9832_1.png: Một chiếc giường với ga trải giường và gối trắng trong một căn phòng nhỏ
# image_221_0.png: Một người đàn ông ngồi trên ghế cạnh một vũng nước
# image_23027_0.png: Một cái giường với một tấm vải trắng trên đầu
# image_24250_0.png: Một người phụ nữ đứng giữa đường với những tòa nhà ở phía sau
# image_16534_5.png: Một người phụ nữ đứng trước một ngôi nhà
# image_7101_6.png: Một vùng nước rộng lớn
# image_29452_2.png: Một phòng khách sạn với một chiếc giường và một tấm gương lớn
# image_27272_5.png: một cái hồ bơi với một chiếc thuyền ở giữa
# image_26882_2.png: một khu bếp và ăn uống trong một căn hộ nhỏ
# image_1645_0.png: một người đang cầm một cái cây trước bức tường xanh
# image_19354_1.png: Một phòng khách sạn có giường và ghế
# image_6768_3.png: Cửa tủ lạnh đang mở.
# image_34066_1.png: Một người phụ nữ đứng trước cửa sổ nhìn vào điện thoại
# image_28246_3.png: Một bữa tiệc buffet tại một nhà hàng với rất nhiều thức ăn trên đó
# image_19056_0.png: nhìn ra đại dương từ đỉnh đồi
# image_18134_0.png: Một vùng nước rộng lớn
#
# Generating Captions:   2%|▌                    | 14/573 [01:10<42:10,  4.53s/it]image_25897_4.png: một cái nhìn ra biển từ sàn nhà
# image_19272_0.png: một cái ghế ngồi trước cửa sổ nhìn ra biển
# image_26790_2.png: Một người phụ nữ đứng trước tấm biển ghi " mela "
# image_27181_0.png: Một cái bàn đầy bánh ngọt và bánh ngọt
# image_16394_3.png: Một cô bé ngồi trên giường
# image_23714_2.png: một khu vườn với một lối đi bằng đá dẫn đến một ngôi nhà
# image_24131_0.png: một cái nhìn ra biển từ sàn nhà
# image_28317_5.png: Một người phụ nữ đứng trước bể bơi
# image_1001_1.png: Một phòng khách với một chiếc ghế dài một cái bàn và một cái gương
# image_341_0.png: một cái giường ngồi trên một cái giường cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng cứng
# image_27768_0.png: Quang cảnh thành phố vào ban đêm từ đỉnh đồi
# image_27495_0.png: Một người phụ nữ ngồi tại bàn với hai đứa con
# image_1150_0.png: Một căn phòng với một cái bàn và ghế trong đó
# image_8943_2.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_21104_0.png: Một chiếc xe đậu bên vệ đường vào ban đêm
# image_7976_1.png: Một đám thuyền nổi trên mặt nước rộng lớn.
# image_11623_0.png: Một người đàn ông đứng trước một tòa nhà với một chiếc vali
# image_18862_0.png: một góc nhìn ra bãi biển với một băng ghế ở phía trước
# image_23543_3.png: Một người phụ nữ ngồi trên ghế xích đu dưới gốc cây
# image_324_3.png: ba người ngồi trên ghế dài trong phòng khách
# image_15216_6.png: thuyền trên mặt nước vào ban đêm với đèn chiếu sáng trên đó
# image_7623_1.png: một phòng khách sạn với giường, bàn và ti vi
# image_18464_0.png: một cái đĩa trắng với các loại thức ăn khác nhau ở trên
# image_22811_0.png: một cái bàn thuỷ tinh với hoa quả và một chai rượu vang
# image_2151_4.png: Một phụ nữ mặc váy đen đứng trên ban công
# image_20184_1.png: một phòng khách sạn có giường và bồn tắm
# image_16_5.png: Một ngôi nhà trên một ngọn đồi với những cái cây ở phía sau
# image_9512_0.png: một phòng khách sạn có ti vi và hành lý
# image_19601_3.png: một cái sân với một cái bàn và ghế dưới một cái ô
# image_30801_0.png: Một người đàn ông ngồi trên ghế đọc sách
# image_17836_0.png: một phòng khách nhìn ra biển
# image_11095_1.png: - Một phòng khách sạn có hai giường và một bàn làm việc. '
#
# Generating Captions:   3%|▌                    | 15/573 [01:15<42:48,  4.60s/it]image_24857_0.png: một chiếc ti vi đặt trên một chiếc tủ gỗ
# image_6758_3.png: một em bé trong hố bóng bao quanh bởi bóng bay
# image_20371_1.png: một bãi biển với rất nhiều người trên đó.
# image_24084_1.png: cho bán lô / đất / trang trại cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu cebu
# image_1601_0.png: Một cô bé ngồi trên giường nhìn ra cửa sổ
# image_15953_3.png: Một phòng khách sạn với cửa sổ lớn và rèm cửa
# image_18117_0.png: nhìn ra đại dương từ cửa sổ nhà hàng
# image_7328_0.png: phòng tắm có bồn cầu và gương
# image_15235_2.png: một cái sân với một cái bàn và ghế bên cạnh một cái cây
# image_4365_2.png: một cái nhìn toàn cảnh thành phố từ mái nhà
# image_34090_0.png: một căn phòng với sàn gỗ và cửa trượt
# image_20736_3.png: Một phòng khách đầy đồ đạc và một cửa sổ lớn
# image_3685_2.png: khung cảnh một thị trấn nhỏ trong sương mù
# image_28503_0.png: một người thả diều trên bãi biển
# image_9402_0.png: Một người đàn ông ngồi trên ghế trong phòng khách sạn
# image_31565_0.png: một sàn lát gạch trắng đen
# image_15691_0.png: Một tòa nhà màu trắng với một tấm biển màu xanh lá cây ở mặt trước
# image_32419_3.png: một cái giường có đèn trên đầu
# image_24432_0.png: một hộp nhựa đựng đầy thức ăn bên cạnh một chai rượu vang
# image_822_1.png: Một sàn nhà kẻ ca rô đen trắng
# image_3403_2.png: một biển hiệu màu vàng trên một cái cột trước một toà nhà
# image_1299_0.png: - một cái giường có ga trải giường và gối trắng. '
# image_28917_2.png: Một cặp chim đậu trên một cái cây
# image_11007_3.png: Nội thất của một nhà hàng với những bức tường kính
# image_34439_0.png: Hai người chụp ảnh trước cây thông noel
# image_26127_3.png: một hình chụp điện thoại trên bàn
# image_27153_1.png: một cảnh nhìn ra một vùng nước từ cửa sổ
# image_15347_6.png: phòng tắm có nhà vệ sinh và vòi hoa sen
# image_27887_2.png: Một căn phòng với những bức tường xanh lá cây và hai cửa sổ
# image_29022_0.png: khung cảnh thành phố từ cửa sổ
# image_26607_2.png: Một hồ bơi nhìn ra biển
# image_26050_0.png: một con gấu bông ngồi trên một chiếc va li
#
# Generating Captions:   3%|▌                    | 16/573 [01:20<42:53,  4.62s/it]image_23316_2.png: một người đàn ông trên ván trượt trong một vùng nước
# image_17998_3.png: Một phòng khách sạn có bể bơi
# image_27771_1.png: Một người đàn ông và một người phụ nữ trong hồ bơi
# image_7054_1.png: bầu trời xanh với những đám mây trắng
# image_16052_3.png: hai giường trong một phòng khách sạn
# image_17685_0.png: góc nhìn thành phố từ trên đỉnh toà nhà
# image_19852_0.png: một bể bơi với ghế và nhìn ra biển
# image_1379_1.png: một phòng khách với một TV màn hình phẳng trên tường
# image_3547_3.png: một cái nhìn về thành phố từ đỉnh đồi
# image_22529_1.png: Một cái bàn gỗ đặt trên một cái sàn gỗ bên cạnh đại dương
# image_8646_0.png: Một căn phòng với những bức tường trắng và một ngọn đèn trần
# image_29486_0.png: Một người đàn ông mặc áo khoác màu xanh
# image_16722_0.png: một cái bàn với một bát trái cây và một đĩa trái cây
# image_18689_0.png: Một người phụ nữ ngồi tại bàn với một đĩa thức ăn
# image_16326_4.png: Bàn và ghế trong phòng khách sạn
# image_14708_4.png: sảnh khách sạn với sàn ca rô đen trắng
# image_22693_2.png: Một người đàn ông ngồi ăn tại bàn
# image_24083_0.png: Một cô bé đứng trước bể bơi
# image_14377_2.png: một hồ bơi ngoài trời với ghế dài và cây cối ở phía sau
# image_18476_2.png: Một vùng nước rộng lớn
# image_14371_1.png: Lối vào một nhà hàng với một tấm biển phía trên nó
# image_3056_1.png: Một căn phòng với một cái ghế và một cửa sổ
# image_5476_0.png: Hai người ngồi trên ghế nhìn ra cửa sổ vào ban đêm
# image_20749_2.png: Một người đàn ông và một cô bé ngồi ở bàn ăn.
# image_26987_0.png: Một phòng khách đầy đồ đạc và một ti vi màn hình phẳng
# image_21037_2.png: Hai giường trong một phòng khách sạn với một bức tranh trên tường
# image_26334_0.png: Một người ngồi trên ghế bành trước màn hình phẳng của một chiếc tivi
# image_22745_2.png: nhìn ra biển từ ban công của khách sạn
# image_21125_1.png: một hồ bơi với cây cọ ở phía sau
# image_27372_3.png: Một tòa nhà lớn màu trắng với một chiếc đồng hồ trên đỉnh.
# image_16537_0.png: một sân golf với một biển hiệu ghi lời chào mừng đến golf châu á
# image_3209_0.png: Một phòng ngủ với sàn gỗ và tường trắng
#
# Generating Captions:   3%|▌                    | 17/573 [01:23<39:01,  4.21s/it]image_15046_0.png: một chiếc giường trong một căn phòng có một vòng tròn màu xanh trên tường
# image_29504_0.png: Một người đàn ông đứng cạnh một người phụ nữ đang ngồi trên ghế
# image_27180_0.png: Một phụ nữ mặc váy xanh đang đứng trên ban công
# image_18401_1.png: Một người đàn ông đứng giữa vườn hoa
# image_27476_0.png: nhìn ra đại dương từ cửa sổ
# image_21876_0.png: Bãi biển với cây cọ và ghế dưới bầu trời xanh
# image_32007_2.png: một cái gối có hình ngôi sao trên đó
# image_17900_1.png: nhìn ra bãi biển và đại dương từ trên đỉnh của một toà nhà
# image_20148_0.png: Quang cảnh thành phố vào ban đêm từ đỉnh của một toà nhà
# image_15582_5.png: Một bồn tắm nóng đặt trên sàn gỗ
# image_15616_2.png: một cái nhìn ra hồ bơi vào ban đêm với ghế dài và ô
# image_2631_1.png: một phòng khách sạn có giường và ti vi
# image_25249_3.png: Một tòa nhà cao với cây cối mọc bên cạnh
# image_21037_1.png: Một ly nước đặt trên bàn gỗ
# image_26893_1.png: Một tòa nhà cao với nhiều balks trên balks
# image_33273_1.png: Lối vào khách sạn vào ban đêm
# image_2040_0.png: một cái giường với một con gấu bông ngồi trên đầu giường
# image_25807_0.png: Một ngôi nhà trắng với những cây xanh trong sân
# image_15958_0.png: Một bó hoa trắng trong bình đen đặt trên bàn
# image_19698_3.png: một cảnh của một thành phố với những ngọn núi ở phía sau
# image_26648_0.png: Một bình hoa đặt trên chiếc đàn piano
# image_28227_3.png: phòng tắm với bồn rửa mặt và tủ gỗ
# image_1059_2.png: Cảnh núi non từ cửa sổ tàu hoả
# image_26666_0.png: Một người đàn ông đứng trong một phòng khách sạn cạnh một chiếc giường
# image_913_2.png: Một bồn tắm màu trắng nằm trên sàn lát gạch
# image_19823_5.png: một chiếc tivi gắn trên tường gạch trong phòng ngủ
# image_33832_3.png: phòng tắm có bồn rửa mặt và gương
# image_22214_3.png: một người phụ nữ ngồi trên một cái giăm bông trên một cái giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông giăm bông
# image_17999_0.png: chân của một người trên bờ hồ bơi với đại dương ở phía sau
# image_23478_4.png: một phòng khách với một chiếc tivi và một cái ghế
# image_24651_1.png: Một cái bàn gỗ đặt trên một sàn gỗ
# image_12485_0.png: phòng tắm có bồn cầu, bồn rửa mặt và vòi hoa sen
#
# Generating Captions:   3%|▋                    | 18/573 [01:27<39:09,  4.23s/it]image_27758_1.png: Một đĩa mì ống với thịt và nước sốt
# image_1770_0.png: Một phòng khách với những bức tường màu đen và một chiếc ghế dài màu xanh.
# image_3138_0.png: một phòng ngủ với một chiếc giường trắng và một tấm gương trên tường
# image_11289_0.png: Một căn phòng nhìn ra sông và cây cầu
# image_8286_1.png: một phòng khách với đồ gỗ và cây cối
# image_26868_1.png: Mặt trời đang lặn trên đường chân trời thành phố.
# image_23030_0.png: - Một bể bơi lớn có ghế và ô.
# image_15580_6.png: một cái sân với một cái bàn và ghế trên đó
# image_398_0.png: một chiếc giường với ga trải giường và gối trắng trong phòng khách sạn
# image_1500_2.png: Một chiếc giường trắng trong phòng ngủ cạnh cửa sổ
# image_16534_2.png: chân của một người trên một chiếc khăn tắm trên bãi biển
# image_11572_0.png: Một cái bàn với một khay thức ăn trên đó
# image_3808_0.png: Quang cảnh thành phố từ bàn ăn nhà hàng
# image_19392_1.png: nhìn ra đại dương lúc hoàng hôn từ ban công
# image_1050_6.png: một cái bàn với bát thức ăn và bát súp
# image_9751_0.png: Hai đĩa thức ăn trên bàn trong phòng khách
# image_26888_0.png: nhìn ra đại dương từ trên đỉnh một toà nhà
# ...
# image_19349_1.png: Một phòng khách sạn có giường và ghế
# image_27381_0.png: một người cầm hộ chiếu trên tay
# image_344_0.png: Một tòa nhà màu trắng với một cái đồng hồ bên cạnh
# image_20394_0.png: phòng tắm với hai bồn rửa và một bồn tắm
# image_10827_4.png: Lối vào một khách sạn ở Bangkok
# image_23608_0.png: phòng tắm có bồn cầu, bồn rửa mặt và vòi hoa sen
#
# Generating Captions:  99%|███████████████████▋| 565/573 [43:21<00:29,  3.69s/it]image_26378_4.png: một người ngồi trên ghế bành trước cửa sổ
# image_25362_3.png: Cảnh hoàng hôn từ ban công của một khách sạn ở thái lan
# image_16140_3.png: Một phòng ngủ với một chiếc giường lớn và một bức tranh trên tường
# image_32545_2.png: một cái giá đựng chén đĩa bên trong
# image_5822_2.png: Một người phụ nữ chụp ảnh mình trên điện thoại
# image_19563_3.png: Một cái đĩa trắng phủ dưa hấu và dưa chua trên bàn gỗ
# image_7425_0.png: Một phụ nữ chụp ảnh tự sướng trong phòng khách sạn
# image_27112_1.png: Một đĩa thức ăn trên bàn gỗ
# image_8011_2.png: một hồ bơi trong nhà với tầm nhìn ra thành phố
# image_832_0.png: Đây là một nhà hàng.
# image_4120_0.png: Một con gấu bông ngồi trước kệ sách
# image_14189_0.png: Phòng tắm màu đen trắng với bồn tắm
# image_27113_3.png: một cái nhìn ra bãi biển và đại dương từ đỉnh đồi
# image_32045_0.png: Quang cảnh thành phố vào ban đêm từ đỉnh của một toà nhà
# image_1229_0.png: một phòng ngủ với một cái giường và một cánh cửa trượt
# image_27752_2.png: một cái giường với chăn bông trắng và một cái ti vi treo trên tường.
# image_22060_3.png: một phòng tắm có nhà vệ sinh và vòi hoa sen bên trong
# image_33143_1.png: Một phòng khách sạn có giường và ghế dài
# image_7923_0.png: Một cậu bé đứng trước giường trong một phòng khách sạn
# image_6314_1.png: Cảnh bãi biển từ cửa sổ
# image_29532_1.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_18557_0.png: một cái ba lô đen trắng, một cái ba lô đen trắng, một cái ba lô đen trắng, và một cái ba lô đen trắng.
# image_24745_0.png: Một hồ bơi lớn được bao quanh bởi những cây cọ
# image_21937_0.png: Một người phụ nữ đứng trước một tòa nhà màu xanh và trắng
# image_19090_0.png: Một người phụ nữ đi qua một cái cây có treo đèn đỏ
# image_3209_2.png: Một chiếc giường trắng trong phòng ngủ cạnh cửa sổ
# image_24819_1.png: Một phòng khách sạn nhìn ra biển
# image_6293_5.png: cảnh hoàng hôn từ ban công của một toà nhà chung cư
# image_20010_0.png: Một căn phòng nhìn ra biển
# image_21667_0.png: Những cây cọ bên vệ đường
# image_12016_1.png: một tờ giấy trắng đặt trên bàn
# image_3894_4.png: một tòa nhà với tấm biển đề khách sạn trung tâm
#
# Generating Captions:  99%|███████████████████▊| 566/573 [43:26<00:26,  3.79s/it]image_5165_3.png: góc nhìn ra đường từ một nhà hàng
# image_3082_2.png: Một người phụ nữ ngồi trên ghế trước một ngôi nhà
# image_18127_0.png: Một người phụ nữ ngồi trên giường trước cửa sổ nhìn ra biển
# image_10550_1.png: - Một cửa sổ có rèm treo bên cạnh
# image_21124_1.png: Một hàng cây cọ trước một toà nhà màu trắng
# image_1305_0.png: Một phòng khách với một chiếc ghế dài và một bức tranh trên tường
# image_30832_4.png: một chiếc giường với ga trải giường và gối trắng trong phòng khách sạn
# image_10827_0.png: Một phòng khách sạn với giường và sàn gỗ
# image_26064_1.png: một người đang cầm một đĩa trái cây trên bàn
# image_10210_5.png: Một cái đĩa trắng có thức ăn trên đó
# image_12368_1.png: Một căn phòng với một cánh cửa gỗ và một tấm bảng trên cửa
# image_22108_2.png: một hồ bơi ngoài trời với những cây cọ bao quanh
# image_14345_0.png: Một người đàn ông ngồi trên ghế trước khách sạn
# image_6751_1.png: Bảng phấn trên bàn
# image_31852_0.png: Một người phụ nữ ngồi trên giường trong một phòng khách sạn
# image_12346_2.png: một bồn tắm màu trắng trong phòng tắm
# image_1048_1.png: Một người phụ nữ đứng trước một nhà trắng
# image_27537_1.png: Một người đàn ông bế một đứa bé trong sảnh khách sạn
# image_5094_4.png: một biển hiệu ở trước một tòa nhà
# image_18678_0.png: nhìn ra đại dương từ một con phố với những cây cọ
# image_2967_1.png: Ban công có chậu cây và chậu cây
# image_19815_1.png: Một người phụ nữ mặc váy đen đứng trước cây thông noel
# image_18486_0.png: Một cái bàn thuỷ tinh với một bát thức ăn trên đó
# image_16741_3.png: Một cánh đồng xanh với những cây cọ và một toà nhà ở phía sau
# image_27375_0.png: một phòng ngủ với một chiếc giường trắng và một chiếc ghế màu xanh
# image_15950_0.png: Một phòng khách sạn nhìn ra thành phố
# image_7069_3.png: Một chiếc ti vi màn hình phẳng đặt trên một kệ gỗ
# image_4405_0.png: một ban công nhìn ra thành phố vào ban đêm
# image_30535_0.png: - Một phòng khách sạn có hai giường và một bàn làm việc. '
# image_19571_0.png: Bể bơi ở khách sạn ở Bangkok.
# image_14446_1.png: một cái bồn cầu màu trắng trong phòng tắm cạnh bồn tắm
# image_23896_5.png: Một phụ nữ mặc váy và đội mũ đứng trên xích đu
#
# Generating Captions:  99%|███████████████████▊| 567/573 [43:29<00:22,  3.70s/it]image_24581_2.png: Một đám xe máy đậu trước một ngôi nhà
# image_17831_1.png: Hai giường trong phòng khách sạn có bàn ghế
# image_23799_2.png: một ngôi nhà với bãi cỏ trước mặt
# image_23018_4.png: Một người phụ nữ đứng trên ban công nhìn ra biển
# image_27319_1.png: Một phòng ngủ với một cái giường và một cửa sổ lớn
# image_29411_1.png: Một phòng khách sạn với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_25578_0.png: một cái cây trên mặt bàn cạnh một cái gương
# image_3438_0.png: Một người phụ nữ đứng trước một tấm biển ghi là dal boutique
# image_22818_0.png: Một hồ bơi lớn có người ở trong.
# image_21808_1.png: Một vài ngôi nhà với những cây cọ ở phía sau
# image_5220_1.png: Một hồ bơi với những viên gạch màu xanh trên sàn
# image_28311_0.png: Những cây cọ trên nền trời xanh
# image_99_0.png: Một người đàn ông đứng trước một tấm biển trên nóc một tòa nhà
# image_26099_2.png: Một người phụ nữ nằm trên một túi đậu trên sàn nhà
# image_5155_0.png: Hai phụ nữ đứng trước một nhà hàng với những chiếc ô màu xanh
# image_6025_0.png: Một người phụ nữ đứng trên ban công với hoàng hôn phía sau
# image_15292_0.png: một tòa nhà với một cái cây ở phía trước nó
# image_8032_0.png: một người nằm trên giường trong phòng
# image_6611_0.png: một căn phòng với một tấm gương và một kệ gỗ
# image_26672_1.png: Một cậu bé đứng trên giường trong một phòng khách sạn
# image_24740_1.png: Một cái nhìn bằng gỗ với một cái bàn và ghế trên cỏ
# image_28919_4.png: nhìn ra biển từ một căn hộ cao tầng
# image_1497_1.png: Toà nhà màu trắng và nâu.
# image_27897_2.png: một người đang cầm một ly yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo
# image_6160_2.png: nhìn ra đại dương từ phòng khách sạn
# image_21697_1.png: Một cái bàn gỗ với những đĩa thức ăn trên đầu
# image_22022_0.png: Một người phụ nữ đứng cạnh bể bơi
# image_14530_1.png: phòng tắm có bồn rửa mặt, nhà vệ sinh và gương
# image_23705_1.png: Một bãi biển với những người đi bộ dọc theo nó
# image_1057_0.png: Một người phụ nữ đứng trước một ngôi nhà trắng có mái đỏ
# image_23677_0.png: Con đường dẫn đến các túp lều trong khu nghỉ mát.
# image_28843_0.png: một phòng khách với một TV màn hình phẳng trên tường
#
# Generating Captions:  99%|███████████████████▊| 568/573 [43:33<00:18,  3.76s/it]image_23176_0.png: một cái bóng của một người trên bãi biển
# image_6628_1.png: Quang cảnh thành phố vào ban đêm từ đỉnh của một toà nhà
# image_6674_1.png: Một người phụ nữ đứng trong hồ bơi nhìn vào một tòa nhà
# image_219_1.png: Một đứa bé đang ngồi trên ghế trong phòng khách
# image_7446_4.png: Một người đàn ông trong hồ bơi với một con chó
# image_28583_0.png: Một nhà hàng với bàn ghế gỗ
# image_9578_0.png: một chiếc giường nằm trong phòng ngủ cạnh cửa sổ
# image_29020_0.png: phòng tắm có bồn cầu, bồn rửa mặt và vòi hoa sen
# image_10142_0.png: một căn phòng với một cái bàn và một cái ti vi
# image_24909_0.png: một phòng ngủ với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_16611_0.png: Trời đầy mây
# image_2704_3.png: một nhóm cây xương rồng trước bức tường trắng
# image_19748_0.png: nhìn ra biển từ ban công tại khu nghỉ mát
# image_14651_0.png: Một người đàn ông và một người phụ nữ đứng trước một ngôi nhà
# image_20673_2.png: nhìn ra biển và núi từ ban công
# image_7_0.png: Một người phụ nữ ngồi trên ghế trước một cái hồ
# image_5489_2.png: nhìn ra đại dương từ trên đỉnh một toà nhà
# image_31429_0.png: một đèn chùm lớn ở giữa sảnh
# image_18122_0.png: một người đàn ông và một người phụ nữ ngồi ăn tại bàn
# image_21873_4.png: Một người ngồi trên ghế băng trên bãi biển vào ban đêm
# image_29526_0.png: Một phòng khách sạn có giường và ghế
# image_27324_1.png: Một cây cọ giữa bể bơi
# image_28276_0.png: Một người phụ nữ đứng trước bể bơi vào ban đêm
# image_26885_3.png: một cặp đôi đang chơi trong hồ bơi
# image_23059_4.png: Một ngọn đèn đường với một con chim trên lưng
# image_32080_1.png: Thùng rác đặt trên sàn cạnh nhà vệ sinh
# image_19801_0.png: Một người nằm trên bãi biển dưới một chiếc dù
# image_18415_3.png: Một người phụ nữ đứng trên boong tàu nhìn ra biển
# image_5827_4.png: Một người phụ nữ ngồi trên ghế, cầm một bó hoa
# image_24535_0.png: Một bát súp đặt trên bàn
# image_18845_0.png: Một nhà vệ sinh màu trắng bên cạnh một phòng tắm
# image_18003_1.png: Một phòng khách sạn có giường và ghế
#
# Generating Captions:  99%|███████████████████▊| 569/573 [43:37<00:15,  3.77s/it]image_20471_0.png: Một người đàn ông đứng bên cạnh hồ bơi
# image_27179_4.png: một phòng tắm với vòi hoa sen và nhà vệ sinh đi bộ
# image_21465_3.png: một toà nhà với mái lợp tranh
# image_33388_0.png: Một con mèo trắng ngồi trên một cái bàn gỗ
# image_5747_0.png: Một phòng khách sạn hai giường và một TV màn hình phẳng
# image_21838_5.png: một khung cảnh khu vườn qua cửa sổ
# image_14121_2.png: Ban công có bàn và ghế trên đó
# image_27871_1.png: Một nhóm người đang bơi trong hồ
# image_24248_1.png: Một người phụ nữ ngồi trên bãi biển nhìn ra biển
# image_22703_2.png: Một cửa sổ gỗ với tầm nhìn ra hồ nước và những cây cọ
# image_17143_3.png: một sân với ghế và bàn cạnh bể bơi
# image_22503_1.png: Hồ bơi ở khách sạn.
# image_32528_0.png: một chiếc giường trong một phòng khách sạn với một tấm ván đầu màu xanh
# image_8053_3.png: Một người phụ nữ đứng trên cầu nhìn xuống nước
# image_13532_2.png: Hai giường trong một phòng khách sạn nhìn ra thành phố
# image_12163_2.png: bên trong tủ lạnh với cửa mở
# image_23904_5.png: Một bến cảng với một chiếc thuyền trên đó lúc hoàng hôn
# image_16926_0.png: một vùng nước
# image_19475_0.png: Xe đậu bên đường ban đêm
# image_2325_0.png: Một người phụ nữ ngồi tại bàn với những đĩa thức ăn
# image_25808_3.png: Một túp lều trên bãi biển lúc hoàng hôn
# image_11349_1.png: Một hồ bơi có ô che bên trên
# image_22240_0.png: Một tòa nhà màu vàng với cây cọ và bầu trời xanh ở phía sau
# image_18416_1.png: một hồ bơi với những người đang bơi trong đó và cây cọ ở phía sau
# image_7463_0.png: một đĩa thức ăn và một ly bia trên bàn
# image_5624_4.png: Một bình hoa trắng đỏ đặt trên bàn
# image_23371_1.png: một căn phòng với một bức tường đá và đồ nội thất bằng gỗ
# image_14953_4.png: Một số ngôi nhà và cây cọ
# image_25514_3.png: Một hồ bơi nhìn ra biển
# image_7346_1.png: Quang cảnh thành phố từ mặt nước
# image_15892_0.png: Một toà nhà với một tấm biển ở mặt trước
# image_5768_5.png: một cái nhìn từ trên không của khu nghỉ mát từ đỉnh đồi
#
# Generating Captions:  99%|███████████████████▉| 570/573 [43:40<00:10,  3.66s/it]image_18399_2.png: Một nhóm người tạo dáng cho một bức ảnh
# image_24580_2.png: một cảnh thành phố từ ban công
# image_9855_0.png: Một hồ bơi lớn được bao quanh bởi những cây cọ
# image_21330_2.png: một phòng ngủ với một chiếc giường lớn và một chiếc ti vi màn hình phẳng
# image_5482_4.png: Sảnh chờ của khách sạn
# image_6767_3.png: Cửa tủ lạnh đang mở.
# image_3139_4.png: góc nhìn thành phố từ đỉnh đồi
# image_28139_0.png: Một người đàn ông ngồi trên ghế trong phòng khách
# image_28356_2.png: Một nhóm người ngồi quanh bàn ăn
# image_30811_3.png: Một phòng khách đầy đồ đạc và một ti vi màn hình phẳng
# image_6293_4.png: Một chậu trồng cây lớn màu trắng nằm bên cạnh một toà nhà
# image_27649_0.png: Một người phụ nữ trong bể bơi ở giữa tòa nhà
# image_17838_1.png: Một phòng khách sạn hai giường và có thể nhìn ra biển
# image_23484_0.png: Một nhóm người ngồi quanh bàn với thức ăn trên đó
# image_17032_3.png: Một khu vườn với rất nhiều cây cối
# image_29428_0.png: Một bình hoa trên bàn trong phòng khách
# image_25243_6.png: Một phòng ngủ với một chiếc giường lớn và một bức tranh trên tường
# image_20734_3.png: Một ngôi nhà gỗ với cầu thang dẫn lên đó
# image_23660_2.png: Một người đàn ông trong chiếc áo choàng tắm đứng trước gương
# image_12810_0.png: Một cô bé nhìn ra ngoài cửa sổ thành phố
# image_17537_2.png: Một căn phòng với sàn gỗ và cửa sổ
# image_7882_5.png: một phòng khách đầy đồ nội thất và một tủ trưng bày bằng kính
# image_23161_2.png: Bãi biển với một chiếc ô lợp mái và một chiếc thuyền trên mặt nước
# image_26882_0.png: phòng tắm có bồn cầu, bồn rửa mặt và gương
# image_14810_0.png: Một cậu bé bơi trong hồ bơi với một con cá heo
# image_1881_0.png: Cảnh sân golf từ phòng khách sạn
# image_13531_1.png: Một người đàn ông trong bồn tắm nước nóng trên mái nhà vào ban đêm
# image_16755_0.png: một phòng ngủ với một chiếc giường lớn và một bức tường dán giấy
# image_15313_2.png: Hồ bơi ở khu nghỉ dưỡng
# image_9954_1.png: - một hồ bơi được bao quanh bởi cây cối và cây cối. '
# image_18657_3.png: Một chiếc ghế dài ngồi giữa một vùng nước
# image_19215_3.png: Một bát trái cây đặt trên bàn gỗ
#
# Generating Captions: 100%|███████████████████▉| 571/573 [43:43<00:07,  3.51s/it]image_33820_0.png: - Một phòng khách sạn có hai giường và một bàn làm việc. '
# image_2214_0.png: Một góc nhìn từ mái của một toà nhà trong thành phố
# image_2216_2.png: Một người phụ nữ ngồi trên ghế dài trong phòng khách
# image_19820_4.png: một cửa sổ với tầm nhìn ra một cái cây bên ngoài
# image_22823_0.png: một dãy giường trong một căn phòng có một bức tường ở phía sau
# image_21125_2.png: một hồ bơi với cây cọ ở phía sau
# image_23640_0.png: một bãi biển với cây cọ và người trên mặt nước
# image_10_0.png: một tấm biển ở lối vào khu nghỉ mát
# image_33377_0.png: Một phòng khách sạn với hai giường và một ghế
# image_6834_2.png: nhìn ra đại dương từ mái của một toà nhà
# image_5703_0.png: Một người phụ nữ ngồi trên ghế dài trong nhà hàng vào ban đêm
# image_32858_2.png: một cửa phòng tắm bằng kính trong phòng tắm
# image_5489_1.png: một hồ bơi dài với thác nước ở giữa hồ
# image_22214_1.png: Một phụ nữ mặc váy trắng đứng cạnh một cây cọ
# image_7528_1.png: Một phụ nữ mặc quần đùi và áo phông đang đứng trên ghế xích đu
# image_9959_0.png: một chiếc giường với ga trải giường và gối trắng trong phòng khách sạn
# image_23488_0.png: Một đĩa cua và một chai bia trên bãi biển
# image_14121_3.png: Một đĩa hàu trên ban công
# image_858_3.png: Hai con mèo nằm trên một kệ gỗ
# image_20375_0.png: nhìn ra đại dương từ bức tường đá
# image_9574_2.png: một buồng tắm bẩn
# image_5483_1.png: một phòng khách nhìn ra biển
# image_31689_1.png: Một con mèo ngồi trên sàn cạnh hộp thức ăn
# image_29140_6.png: phòng tắm có bồn cầu, bồn rửa mặt và vòi hoa sen
# image_4489_4.png: một con mèo ngồi trên giường cạnh cửa sổ
# image_17143_0.png: Một người đàn ông ngồi tại một cái bàn trước một hồ bơi
# image_2164_2.png: một phòng ngủ với giường, tủ quần áo và gương
# image_7882_4.png: Sảnh chờ của một khách sạn với những bông hoa trắng trên sàn
# image_23103_0.png: Một người đàn ông đang tắm trong phòng tắm
# image_365_0.png: Một khung cảnh từ cửa sổ của một ngôi nhà trên đồi
# image_3049_0.png: Một phòng khách với hai ghế và một bàn
# image_22955_3.png: một nhóm cây cọ trước ngôi nhà
#
# Generating Captions: 100%|███████████████████▉| 572/573 [43:47<00:03,  3.45s/it]image_27534_0.png: Một người đàn ông và một người phụ nữ đeo khẩu trang khi nhìn vào điện thoại
# image_25397_5.png: Một người đàn ông ngồi bên cạnh hồ bơi
# image_18781_0.png: một góc nhìn ra đại dương từ một căn hộ ở mumbai
# image_4335_4.png: một quán cà phê ngoài trời với ghế và bàn màu vàng
# image_26376_0.png: một phòng khách với một TV màn hình phẳng
# image_4931_0.png: Một sảnh khách sạn với một bức tranh lớn trên tường
#
# Generating Captions: 100%|████████████████████| 573/573 [43:48<00:00,  4.59s/it]
# Hoàn tất! Caption sạch (không nốt nhạc) đã lưu tại /kaggle/working/ViMACSA/output_EF-CapTrRoBERTa_visual_captions_vi
