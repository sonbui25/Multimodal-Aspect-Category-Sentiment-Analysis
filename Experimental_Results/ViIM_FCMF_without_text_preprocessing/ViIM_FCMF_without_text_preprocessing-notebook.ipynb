# %%
# !rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
# !git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# Out:
# Cloning into 'Multimodal-Aspect-Category-Sentiment-Analysis'...
# remote: Enumerating objects: 1449, done.
# remote: Counting objects: 100% (343/343), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 1449 (delta 324), reused 307 (delta 293), pack-reused 1106 (from 1)
# Receiving objects: 100% (1449/1449), 3.99 MiB | 20.12 MiB/s, done.
# Resolving deltas: 100% (959/959), done.

# %%
#!pip install -r '/kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/requirements.txt'
# !pip install underthesea
# !pip install underthesea_core
# !pip install huggingface-hub==0.17.3
# !pip install transformers==4.35.0
# !pip install bert-score
# !pip install rouge-score
# !pip install protobuf==3.20.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.6/846.6 kB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 17.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.4.1 requires huggingface-hub<2.0,>=0.25.0, but you have huggingface-hub 0.17.3 which is incompatible.
# accelerate 1.11.0 requires huggingface_hub>=0.21.0, but you have huggingface-hub 0.17.3 which is incompatible.
# ...

# %%
# !pip install --upgrade transformers huggingface-hub accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 136.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.0
#     Uninstalling transformers-4.35.0:
#       Successfully uninstalled transformers-4.35.0
# ...

# %%
# !mkdir -p /kaggle/working/ViMACSA/output/pretraining

# %%
#!rm -rf /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis
#!git clone https://github.com/sonbui25/Multimodal-Aspect-Category-Sentiment-Analysis.git
# 0.71 baseline
# !python /kaggle/working/Multimodal-Aspect-Category-Sentiment-Analysis/run_multimodal_fcmf.py \
  --data_dir "/kaggle/input/implicit-vimacsa" \
  --output_dir "/kaggle/working/ViMACSA/output_iaog_fcmf" \
  --image_dir "/kaggle/input/vimacsa/ViMACSA/image" \
  --pretrained_hf_model /kaggle/input/uitnlpvisobert/pytorch/default/1 \
  --pretrained_iaog_path /kaggle/input/iaog-last-checkpoint/pytorch/30_epoch/3/seed_42_iaog_model_last.pth \
  --list_aspect Location Food Room Facilities Service Public_area \
  --num_polarity 4 \
  --num_imgs 7 \
  --num_rois 4 \
  --train_batch_size 4 \
  --eval_batch_size 32 \
  --num_train_epochs 13 \
  --encoder_learning_rate 7e-5 \
  --classifier_head_learning_rate 7e-4 \
  --warmup_proportion 0.1 \
  --gradient_accumulation_steps 2 \
  --do_train \
  --do_eval \
  --fp16 \
  --alpha 1
# Out:
# Running on device:0
# ===================== RUN Fine-grained Cross-modal Fusion (MACSA) =====================
# 01/25/2026 01:49:46 - INFO - __main__ - device: cuda n_gpu: 1, distributed training: False, 16-bits training: True
# 01/25/2026 01:49:46 - INFO - __main__ - ROI DataFrame loaded with 14633 entries.
# 01/25/2026 01:49:47 - INFO - __main__ - Image aspect categories loaded with 18310 entries.
# 01/25/2026 01:49:47 - INFO - __main__ - ROI aspect categories loaded with 5901 entries.
# 2026-01-25 01:49:48.820985: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769305789.018033     117 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# Link: https://www.kaggle.com/code/dryiiii/vimacsa-image-trained-hoaqa/notebook?scriptVersionId=293759936
#
# Version 17
